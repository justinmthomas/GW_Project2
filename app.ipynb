# %%
#pip install flask-cors

# %%
import pandas as pd
import sqlalchemy
import pymysql
import sys
from pandas.io.json import json_normalize
pymysql.install_as_MySQLdb()

# %%
from sqlalchemy import create_engine
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session

# %%
from flask import (
    Flask,
    render_template,
    jsonify,
    request)

# %%
from flask_cors import CORS

# %%
from sqlalchemy import create_engine

# %%
#Keep config file for our info. 
from config import remote_db_endpoint, remote_db_port
from config import remote_gwsis_dbname, remote_gwsis_dbuser, remote_gwsis_dbpwd

# %%
#Create Cloud DB Connection. 
engine = create_engine(f"mysql+pymysql://{remote_gwsis_dbuser}:{remote_gwsis_dbpwd}@{remote_db_endpoint}:{remote_db_port}/{remote_gwsis_dbname}")

# %%
# Create remote DB connection.
conn = engine.connect()

# %%
app = Flask(__name__)
CORS(app)

#app.config['SQLALCHEMY_DATABASE_URI'] = ""

#db = SQLAlchemy(app)

# %%
@app.route('/postjson', methods = ['POST'])
def postJsonHandler():
    print (request.is_json)
    # read in JSON from POST requuest into content 
    content = request.get_json()
    print(content)
    
    
    #extract Survey ID from first entry in JSON "Survey ID"
    survey_id = (content["Survey_ID"])
    print(survey_id)
    
    
    ## Create Survey Dataframe form "result" entry in JSON
    survey_df = pd.DataFrame(content["result"])
   
    #set column names of dataframe
   
   
    survey_df.insert(0, "Survey_ID", 'null')
    survey_df["Survey_ID"] = survey_id
    survey_df.columns = ["Survey_ID", "value", "Data_Type", "Chart_Type", "Correct"]
    print (survey_df)
       
    #[print(key, value) for key, value in content.items()] 
  
    #write surve.df to SQL 
    survey_df.to_sql(con=conn, name='survey_results', if_exists='append', index=False)
    #session.commit()
    return jsonify(content)

#     for key, value in content.items():
#         setattr(survey_results, key, value) 


app.run(host='127.0.0.1', port= 5000)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [02/Feb/2020 13:36:39] "OPTIONS /postjson HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Feb/2020 13:36:39] "POST /postjson HTTP/1.1" 200 -
# True
# {'Survey_ID': '0d827a62a258dfe15b3b491ae639d73594810b6da74223b6d8', 'result': [{'value': 'sq_101', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Bar_1', 'Correct': 1}, {'value': 'sq_102', 'Data_Type': 'valuevslocation', 'Chart_Type': 'Map_2', 'Correct': 1}, {'value': 'sq_103', 'Data_Type': 'valuevstime', 'Chart_Type': 'Rings_3', 'Correct': 1}, {'value': 'sq_104', 'Data_Type': 'comparison', 'Chart_Type': 'Bar_4', 'Correct': 1}, {'value': 'sq_105', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Bubble_5', 'Correct': 1}, {'value': 'sq_106', 'Data_Type': 'valuevslocation', 'Chart_Type': 'Bar_6', 'Correct': 1}, {'value': 'sq_107', 'Data_Type': 'valuevsvalue', 'Chart_Type': 'Bubble_7', 'Correct': 1}, {'value': 'sq_108', 'Data_Type': 'valuevstime', 'Chart_Type': 'Table_8', 'Correct': 1}, {'value': 'sq_109', 'Data_Type': 'comparison', 'Chart_Type': 'Table_9', 'Correct': 1}, {'value': 'sq_110', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Tree_10', 'Correct': 1}, {'value': 'sq_111', 'Data_Type': 'valuevsvalue', 'Chart_Type': 'Scatter_11', 'Correct': 1}, {'value': 'sq_112', 'Data_Type': 'comparison', 'Chart_Type': 'Pie_12', 'Correct': 1}, {'value': 'sq_113', 'Data_Type': 'valuevstime', 'Chart_Type': 'Line_13', 'Correct': 1}, {'value': 'sq_114', 'Data_Type': 'valuevslocation', 'Chart_Type': 'Map_14', 'Correct': 1}, {'value': 'sq_115', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Pie_15', 'Correct': 1}]}
# 0d827a62a258dfe15b3b491ae639d73594810b6da74223b6d8
#                                             Survey_ID   value  \
# 0   0d827a62a258dfe15b3b491ae639d73594810b6da74223...  sq_101
# 1   0d827a62a258dfe15b3b491ae639d73594810b6da74223...  sq_102
# 2   0d827a62a258dfe15b3b491ae639d73594810b6da74223...  sq_103
# 3   0d827a62a258dfe15b3b491ae639d73594810b6da74223...  sq_104
# 4   0d827a62a258dfe15b3b491ae639d73594810b6da74223...  sq_105
# 5   0d827a62a258dfe15b3b491ae639d73594810b6da74223...  sq_106
# 6   0d827a62a258dfe15b3b491ae639d73594810b6da74223...  sq_107
# 7   0d827a62a258dfe15b3b491ae639d73594810b6da74223...  sq_108
# 8   0d827a62a258dfe15b3b491ae639d73594810b6da74223...  sq_109
# 9   0d827a62a258dfe15b3b491ae639d73594810b6da74223...  sq_110
# 10  0d827a62a258dfe15b3b491ae639d73594810b6da74223...  sq_111
# 11  0d827a62a258dfe15b3b491ae639d73594810b6da74223...  sq_112
# 12  0d827a62a258dfe15b3b491ae639d73594810b6da74223...  sq_113
# 13  0d827a62a258dfe15b3b491ae639d73594810b6da74223...  sq_114
# 14  0d827a62a258dfe15b3b491ae639d73594810b6da74223...  sq_115
#
#           Data_Type  Chart_Type  Correct
# 0   categoryvsvalue       Bar_1        1
# 1   valuevslocation       Map_2        1
# 2       valuevstime     Rings_3        1
# 3        comparison       Bar_4        1
# 4   categoryvsvalue    Bubble_5        1
# 5   valuevslocation       Bar_6        1
# 6      valuevsvalue    Bubble_7        1
# 7       valuevstime     Table_8        1
# 8        comparison     Table_9        1
# 9   categoryvsvalue     Tree_10        1
# 10     valuevsvalue  Scatter_11        1
# 11       comparison      Pie_12        1
# 12      valuevstime     Line_13        1
# 13  valuevslocation      Map_14        1
# 14  categoryvsvalue      Pie_15        1
# 127.0.0.1 - - [02/Feb/2020 13:38:05] "OPTIONS /postjson HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Feb/2020 13:38:05] "POST /postjson HTTP/1.1" 200 -
# True
# {'Survey_ID': 'fa763cb9c2b2ae4de281945173aaa83f68004940838808c9d6', 'result': [{'value': 'sq_101', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Bar_1', 'Correct': 1}, {'value': 'sq_102', 'Data_Type': 'valuevslocation', 'Chart_Type': 'Map_2', 'Correct': 1}, {'value': 'sq_103', 'Data_Type': 'valuevstime', 'Chart_Type': 'Rings_3', 'Correct': 1}, {'value': 'sq_104', 'Data_Type': 'comparison', 'Chart_Type': 'Bar_4', 'Correct': 1}, {'value': 'sq_105', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Bubble_5', 'Correct': 1}, {'value': 'sq_106', 'Data_Type': 'valuevslocation', 'Chart_Type': 'Bar_6', 'Correct': 1}, {'value': 'sq_107', 'Data_Type': 'valuevsvalue', 'Chart_Type': 'Bubble_7', 'Correct': 1}, {'value': 'sq_108', 'Data_Type': 'valuevstime', 'Chart_Type': 'Table_8', 'Correct': 1}, {'value': 'sq_109', 'Data_Type': 'comparison', 'Chart_Type': 'Table_9', 'Correct': 1}, {'value': 'sq_110', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Tree_10', 'Correct': 1}, {'value': 'sq_111', 'Data_Type': 'valuevsvalue', 'Chart_Type': 'Scatter_11', 'Correct': 1}, {'value': 'sq_112', 'Data_Type': 'comparison', 'Chart_Type': 'Pie_12', 'Correct': 1}, {'value': 'sq_113', 'Data_Type': 'valuevstime', 'Chart_Type': 'Line_13', 'Correct': 1}, {'value': 'sq_114', 'Data_Type': 'valuevslocation', 'Chart_Type': 'Map_14', 'Correct': 1}, {'value': 'sq_115', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Pie_15', 'Correct': 1}]}
# fa763cb9c2b2ae4de281945173aaa83f68004940838808c9d6
#                                             Survey_ID   value  \
# 0   fa763cb9c2b2ae4de281945173aaa83f68004940838808...  sq_101
# 1   fa763cb9c2b2ae4de281945173aaa83f68004940838808...  sq_102
# 2   fa763cb9c2b2ae4de281945173aaa83f68004940838808...  sq_103
# 3   fa763cb9c2b2ae4de281945173aaa83f68004940838808...  sq_104
# 4   fa763cb9c2b2ae4de281945173aaa83f68004940838808...  sq_105
# 5   fa763cb9c2b2ae4de281945173aaa83f68004940838808...  sq_106
# 6   fa763cb9c2b2ae4de281945173aaa83f68004940838808...  sq_107
# 7   fa763cb9c2b2ae4de281945173aaa83f68004940838808...  sq_108
# 8   fa763cb9c2b2ae4de281945173aaa83f68004940838808...  sq_109
# 9   fa763cb9c2b2ae4de281945173aaa83f68004940838808...  sq_110
# 10  fa763cb9c2b2ae4de281945173aaa83f68004940838808...  sq_111
# 11  fa763cb9c2b2ae4de281945173aaa83f68004940838808...  sq_112
# 12  fa763cb9c2b2ae4de281945173aaa83f68004940838808...  sq_113
# 13  fa763cb9c2b2ae4de281945173aaa83f68004940838808...  sq_114
# 14  fa763cb9c2b2ae4de281945173aaa83f68004940838808...  sq_115
#
#           Data_Type  Chart_Type  Correct
# 0   categoryvsvalue       Bar_1        1
# 1   valuevslocation       Map_2        1
# 2       valuevstime     Rings_3        1
# 3        comparison       Bar_4        1
# 4   categoryvsvalue    Bubble_5        1
# 5   valuevslocation       Bar_6        1
# 6      valuevsvalue    Bubble_7        1
# 7       valuevstime     Table_8        1
# 8        comparison     Table_9        1
# 9   categoryvsvalue     Tree_10        1
# 10     valuevsvalue  Scatter_11        1
# 11       comparison      Pie_12        1
# 12      valuevstime     Line_13        1
# 13  valuevslocation      Map_14        1
# 14  categoryvsvalue      Pie_15        1
# 127.0.0.1 - - [02/Feb/2020 16:54:31] "OPTIONS /postjson HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Feb/2020 16:54:31] "POST /postjson HTTP/1.1" 200 -
# True
# {'Survey_ID': 'b95faa96e357e7ef5049e81464526e552b8931deaa7cd8c791', 'result': [{'value': 'sq_101', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Bar_1', 'Correct': 1}, {'value': 'sq_102', 'Data_Type': 'valuevslocation', 'Chart_Type': 'Map_2', 'Correct': 1}, {'value': 'sq_103', 'Data_Type': 'valuevstime', 'Chart_Type': 'Rings_3', 'Correct': 1}, {'value': 'sq_104', 'Data_Type': 'comparison', 'Chart_Type': 'Bar_4', 'Correct': 1}, {'value': 'sq_105', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Bubble_5', 'Correct': 1}, {'value': 'sq_106', 'Data_Type': 'valuevslocation', 'Chart_Type': 'Bar_6', 'Correct': 1}, {'value': 'sq_107', 'Data_Type': 'valuevsvalue', 'Chart_Type': 'Bubble_7', 'Correct': 1}, {'value': 'sq_108', 'Data_Type': 'valuevstime', 'Chart_Type': 'Table_8', 'Correct': 1}, {'value': 'sq_109', 'Data_Type': 'comparison', 'Chart_Type': 'Table_9', 'Correct': 1}, {'value': 'sq_110', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Tree_10', 'Correct': 1}, {'value': 'sq_111', 'Data_Type': 'valuevsvalue', 'Chart_Type': 'Scatter_11', 'Correct': 1}, {'value': 'sq_112', 'Data_Type': 'comparison', 'Chart_Type': 'Pie_12', 'Correct': 1}, {'value': 'sq_113', 'Data_Type': 'valuevstime', 'Chart_Type': 'Line_13', 'Correct': 1}, {'value': 'sq_114', 'Data_Type': 'valuevslocation', 'Chart_Type': 'Map_14', 'Correct': 1}, {'value': 'sq_115', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Pie_15', 'Correct': 1}]}
# b95faa96e357e7ef5049e81464526e552b8931deaa7cd8c791
#                                             Survey_ID   value  \
# 0   b95faa96e357e7ef5049e81464526e552b8931deaa7cd8...  sq_101
# 1   b95faa96e357e7ef5049e81464526e552b8931deaa7cd8...  sq_102
# 2   b95faa96e357e7ef5049e81464526e552b8931deaa7cd8...  sq_103
# 3   b95faa96e357e7ef5049e81464526e552b8931deaa7cd8...  sq_104
# 4   b95faa96e357e7ef5049e81464526e552b8931deaa7cd8...  sq_105
# 5   b95faa96e357e7ef5049e81464526e552b8931deaa7cd8...  sq_106
# 6   b95faa96e357e7ef5049e81464526e552b8931deaa7cd8...  sq_107
# 7   b95faa96e357e7ef5049e81464526e552b8931deaa7cd8...  sq_108
# 8   b95faa96e357e7ef5049e81464526e552b8931deaa7cd8...  sq_109
# 9   b95faa96e357e7ef5049e81464526e552b8931deaa7cd8...  sq_110
# 10  b95faa96e357e7ef5049e81464526e552b8931deaa7cd8...  sq_111
# 11  b95faa96e357e7ef5049e81464526e552b8931deaa7cd8...  sq_112
# 12  b95faa96e357e7ef5049e81464526e552b8931deaa7cd8...  sq_113
# 13  b95faa96e357e7ef5049e81464526e552b8931deaa7cd8...  sq_114
# 14  b95faa96e357e7ef5049e81464526e552b8931deaa7cd8...  sq_115
#
#           Data_Type  Chart_Type  Correct
# 0   categoryvsvalue       Bar_1        1
# 1   valuevslocation       Map_2        1
# 2       valuevstime     Rings_3        1
# 3        comparison       Bar_4        1
# 4   categoryvsvalue    Bubble_5        1
# 5   valuevslocation       Bar_6        1
# 6      valuevsvalue    Bubble_7        1
# 7       valuevstime     Table_8        1
# 8        comparison     Table_9        1
# 9   categoryvsvalue     Tree_10        1
# 10     valuevsvalue  Scatter_11        1
# 11       comparison      Pie_12        1
# 12      valuevstime     Line_13        1
# 13  valuevslocation      Map_14        1
# 14  categoryvsvalue      Pie_15        1
# 127.0.0.1 - - [02/Feb/2020 16:57:35] "OPTIONS /postjson HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Feb/2020 16:57:35] "POST /postjson HTTP/1.1" 200 -
# True
# {'Survey_ID': '445550aa739c72bc0536d2534c9097ebfe05bffdbb41ac1c7f', 'result': [{'value': 'sq_101', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Bar_1', 'Correct': 1}, {'value': 'sq_102', 'Data_Type': 'valuevslocation', 'Chart_Type': 'Map_2', 'Correct': 1}, {'value': 'sq_103', 'Data_Type': 'valuevstime', 'Chart_Type': 'Rings_3', 'Correct': 1}, {'value': 'sq_104', 'Data_Type': 'comparison', 'Chart_Type': 'Bar_4', 'Correct': 1}, {'value': 'sq_105', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Bubble_5', 'Correct': 1}, {'value': 'sq_106', 'Data_Type': 'valuevslocation', 'Chart_Type': 'Bar_6', 'Correct': 1}, {'value': 'sq_107', 'Data_Type': 'valuevsvalue', 'Chart_Type': 'Bubble_7', 'Correct': 1}, {'value': 'sq_108', 'Data_Type': 'valuevstime', 'Chart_Type': 'Table_8', 'Correct': 1}, {'value': 'sq_109', 'Data_Type': 'comparison', 'Chart_Type': 'Table_9', 'Correct': 1}, {'value': 'sq_110', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Tree_10', 'Correct': 1}, {'value': 'sq_111', 'Data_Type': 'valuevsvalue', 'Chart_Type': 'Scatter_11', 'Correct': 1}, {'value': 'sq_112', 'Data_Type': 'comparison', 'Chart_Type': 'Pie_12', 'Correct': 1}, {'value': 'sq_113', 'Data_Type': 'valuevstime', 'Chart_Type': 'Line_13', 'Correct': 1}, {'value': 'sq_114', 'Data_Type': 'valuevslocation', 'Chart_Type': 'Map_14', 'Correct': 1}, {'value': 'sq_115', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Pie_15', 'Correct': 1}]}
# 445550aa739c72bc0536d2534c9097ebfe05bffdbb41ac1c7f
#                                             Survey_ID   value  \
# 0   445550aa739c72bc0536d2534c9097ebfe05bffdbb41ac...  sq_101
# 1   445550aa739c72bc0536d2534c9097ebfe05bffdbb41ac...  sq_102
# 2   445550aa739c72bc0536d2534c9097ebfe05bffdbb41ac...  sq_103
# 3   445550aa739c72bc0536d2534c9097ebfe05bffdbb41ac...  sq_104
# 4   445550aa739c72bc0536d2534c9097ebfe05bffdbb41ac...  sq_105
# 5   445550aa739c72bc0536d2534c9097ebfe05bffdbb41ac...  sq_106
# 6   445550aa739c72bc0536d2534c9097ebfe05bffdbb41ac...  sq_107
# 7   445550aa739c72bc0536d2534c9097ebfe05bffdbb41ac...  sq_108
# 8   445550aa739c72bc0536d2534c9097ebfe05bffdbb41ac...  sq_109
# 9   445550aa739c72bc0536d2534c9097ebfe05bffdbb41ac...  sq_110
# 10  445550aa739c72bc0536d2534c9097ebfe05bffdbb41ac...  sq_111
# 11  445550aa739c72bc0536d2534c9097ebfe05bffdbb41ac...  sq_112
# 12  445550aa739c72bc0536d2534c9097ebfe05bffdbb41ac...  sq_113
# 13  445550aa739c72bc0536d2534c9097ebfe05bffdbb41ac...  sq_114
# 14  445550aa739c72bc0536d2534c9097ebfe05bffdbb41ac...  sq_115
#
#           Data_Type  Chart_Type  Correct
# 0   categoryvsvalue       Bar_1        1
# 1   valuevslocation       Map_2        1
# 2       valuevstime     Rings_3        1
# 3        comparison       Bar_4        1
# 4   categoryvsvalue    Bubble_5        1
# 5   valuevslocation       Bar_6        1
# 6      valuevsvalue    Bubble_7        1
# 7       valuevstime     Table_8        1
# 8        comparison     Table_9        1
# 9   categoryvsvalue     Tree_10        1
# 10     valuevsvalue  Scatter_11        1
# 11       comparison      Pie_12        1
# 12      valuevstime     Line_13        1
# 13  valuevslocation      Map_14        1
# 14  categoryvsvalue      Pie_15        1
# 127.0.0.1 - - [02/Feb/2020 16:58:04] "OPTIONS /postjson HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Feb/2020 16:58:04] "POST /postjson HTTP/1.1" 200 -
# True
# {'Survey_ID': '75eda0836bf63c67bf7fc403f4654075adacf65fdd64cbddb3', 'result': [{'value': 'sq_101', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Bar_1', 'Correct': 1}, {'value': 'sq_102', 'Data_Type': 'valuevslocation', 'Chart_Type': 'Map_2', 'Correct': 1}, {'value': 'sq_103', 'Data_Type': 'valuevstime', 'Chart_Type': 'Rings_3', 'Correct': 1}, {'value': 'sq_104', 'Data_Type': 'comparison', 'Chart_Type': 'Bar_4', 'Correct': 1}, {'value': 'sq_105', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Bubble_5', 'Correct': 1}, {'value': 'sq_106', 'Data_Type': 'valuevslocation', 'Chart_Type': 'Bar_6', 'Correct': 1}, {'value': 'sq_107', 'Data_Type': 'valuevsvalue', 'Chart_Type': 'Bubble_7', 'Correct': 1}, {'value': 'sq_108', 'Data_Type': 'valuevstime', 'Chart_Type': 'Table_8', 'Correct': 1}, {'value': 'sq_109', 'Data_Type': 'comparison', 'Chart_Type': 'Table_9', 'Correct': 1}, {'value': 'sq_110', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Tree_10', 'Correct': 1}, {'value': 'sq_111', 'Data_Type': 'valuevsvalue', 'Chart_Type': 'Scatter_11', 'Correct': 1}, {'value': 'sq_112', 'Data_Type': 'comparison', 'Chart_Type': 'Pie_12', 'Correct': 1}, {'value': 'sq_113', 'Data_Type': 'valuevstime', 'Chart_Type': 'Line_13', 'Correct': 1}, {'value': 'sq_114', 'Data_Type': 'valuevslocation', 'Chart_Type': 'Map_14', 'Correct': 1}, {'value': 'sq_115', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Pie_15', 'Correct': 1}]}
# 75eda0836bf63c67bf7fc403f4654075adacf65fdd64cbddb3
#                                             Survey_ID   value  \
# 0   75eda0836bf63c67bf7fc403f4654075adacf65fdd64cb...  sq_101
# 1   75eda0836bf63c67bf7fc403f4654075adacf65fdd64cb...  sq_102
# 2   75eda0836bf63c67bf7fc403f4654075adacf65fdd64cb...  sq_103
# 3   75eda0836bf63c67bf7fc403f4654075adacf65fdd64cb...  sq_104
# 4   75eda0836bf63c67bf7fc403f4654075adacf65fdd64cb...  sq_105
# 5   75eda0836bf63c67bf7fc403f4654075adacf65fdd64cb...  sq_106
# 6   75eda0836bf63c67bf7fc403f4654075adacf65fdd64cb...  sq_107
# 7   75eda0836bf63c67bf7fc403f4654075adacf65fdd64cb...  sq_108
# 8   75eda0836bf63c67bf7fc403f4654075adacf65fdd64cb...  sq_109
# 9   75eda0836bf63c67bf7fc403f4654075adacf65fdd64cb...  sq_110
# 10  75eda0836bf63c67bf7fc403f4654075adacf65fdd64cb...  sq_111
# 11  75eda0836bf63c67bf7fc403f4654075adacf65fdd64cb...  sq_112
# 12  75eda0836bf63c67bf7fc403f4654075adacf65fdd64cb...  sq_113
# 13  75eda0836bf63c67bf7fc403f4654075adacf65fdd64cb...  sq_114
# 14  75eda0836bf63c67bf7fc403f4654075adacf65fdd64cb...  sq_115
#
#           Data_Type  Chart_Type  Correct
# 0   categoryvsvalue       Bar_1        1
# 1   valuevslocation       Map_2        1
# 2       valuevstime     Rings_3        1
# 3        comparison       Bar_4        1
# 4   categoryvsvalue    Bubble_5        1
# 5   valuevslocation       Bar_6        1
# 6      valuevsvalue    Bubble_7        1
# 7       valuevstime     Table_8        1
# 8        comparison     Table_9        1
# 9   categoryvsvalue     Tree_10        1
# 10     valuevsvalue  Scatter_11        1
# 11       comparison      Pie_12        1
# 12      valuevstime     Line_13        1
# 13  valuevslocation      Map_14        1
# 14  categoryvsvalue      Pie_15        1
# 127.0.0.1 - - [02/Feb/2020 16:58:59] "OPTIONS /postjson HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Feb/2020 16:59:00] "POST /postjson HTTP/1.1" 200 -
# True
# {'Survey_ID': '36101eec2dc4f64dfeae3e04950c59fabd2c4f9a5e71f9ac27', 'result': [{'value': 'sq_101', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Bar_1', 'Correct': 1}, {'value': 'sq_102', 'Data_Type': 'valuevslocation', 'Chart_Type': 'Map_2', 'Correct': 1}, {'value': 'sq_103', 'Data_Type': 'valuevstime', 'Chart_Type': 'Rings_3', 'Correct': 1}, {'value': 'sq_104', 'Data_Type': 'comparison', 'Chart_Type': 'Bar_4', 'Correct': 1}, {'value': 'sq_105', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Bubble_5', 'Correct': 1}, {'value': 'sq_106', 'Data_Type': 'valuevslocation', 'Chart_Type': 'Bar_6', 'Correct': 1}, {'value': 'sq_107', 'Data_Type': 'valuevsvalue', 'Chart_Type': 'Bubble_7', 'Correct': 1}, {'value': 'sq_108', 'Data_Type': 'valuevstime', 'Chart_Type': 'Table_8', 'Correct': 1}, {'value': 'sq_109', 'Data_Type': 'comparison', 'Chart_Type': 'Table_9', 'Correct': 1}, {'value': 'sq_110', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Tree_10', 'Correct': 1}, {'value': 'sq_111', 'Data_Type': 'valuevsvalue', 'Chart_Type': 'Scatter_11', 'Correct': 1}, {'value': 'sq_112', 'Data_Type': 'comparison', 'Chart_Type': 'Pie_12', 'Correct': 1}, {'value': 'sq_113', 'Data_Type': 'valuevstime', 'Chart_Type': 'Line_13', 'Correct': 1}, {'value': 'sq_114', 'Data_Type': 'valuevslocation', 'Chart_Type': 'Map_14', 'Correct': 1}, {'value': 'sq_115', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Pie_15', 'Correct': 1}]}
# 36101eec2dc4f64dfeae3e04950c59fabd2c4f9a5e71f9ac27
#                                             Survey_ID   value  \
# 0   36101eec2dc4f64dfeae3e04950c59fabd2c4f9a5e71f9...  sq_101
# 1   36101eec2dc4f64dfeae3e04950c59fabd2c4f9a5e71f9...  sq_102
# 2   36101eec2dc4f64dfeae3e04950c59fabd2c4f9a5e71f9...  sq_103
# 3   36101eec2dc4f64dfeae3e04950c59fabd2c4f9a5e71f9...  sq_104
# 4   36101eec2dc4f64dfeae3e04950c59fabd2c4f9a5e71f9...  sq_105
# 5   36101eec2dc4f64dfeae3e04950c59fabd2c4f9a5e71f9...  sq_106
# 6   36101eec2dc4f64dfeae3e04950c59fabd2c4f9a5e71f9...  sq_107
# 7   36101eec2dc4f64dfeae3e04950c59fabd2c4f9a5e71f9...  sq_108
# 8   36101eec2dc4f64dfeae3e04950c59fabd2c4f9a5e71f9...  sq_109
# 9   36101eec2dc4f64dfeae3e04950c59fabd2c4f9a5e71f9...  sq_110
# 10  36101eec2dc4f64dfeae3e04950c59fabd2c4f9a5e71f9...  sq_111
# 11  36101eec2dc4f64dfeae3e04950c59fabd2c4f9a5e71f9...  sq_112
# 12  36101eec2dc4f64dfeae3e04950c59fabd2c4f9a5e71f9...  sq_113
# 13  36101eec2dc4f64dfeae3e04950c59fabd2c4f9a5e71f9...  sq_114
# 14  36101eec2dc4f64dfeae3e04950c59fabd2c4f9a5e71f9...  sq_115
#
#           Data_Type  Chart_Type  Correct
# 0   categoryvsvalue       Bar_1        1
# 1   valuevslocation       Map_2        1
# 2       valuevstime     Rings_3        1
# 3        comparison       Bar_4        1
# 4   categoryvsvalue    Bubble_5        1
# 5   valuevslocation       Bar_6        1
# 6      valuevsvalue    Bubble_7        1
# 7       valuevstime     Table_8        1
# 8        comparison     Table_9        1
# 9   categoryvsvalue     Tree_10        1
# 10     valuevsvalue  Scatter_11        1
# 11       comparison      Pie_12        1
# 12      valuevstime     Line_13        1
# 13  valuevslocation      Map_14        1
# 14  categoryvsvalue      Pie_15        1
# 127.0.0.1 - - [02/Feb/2020 17:00:37] "OPTIONS /postjson HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Feb/2020 17:00:37] "POST /postjson HTTP/1.1" 200 -
# True
# {'Survey_ID': '253466c1d3a2db2135c84157f88254a3e04778190a0646781b', 'result': [{'value': 'sq_101', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Bar_1', 'Correct': 1}, {'value': 'sq_102', 'Data_Type': 'valuevslocation', 'Chart_Type': 'Map_2', 'Correct': 1}, {'value': 'sq_103', 'Data_Type': 'valuevstime', 'Chart_Type': 'Rings_3', 'Correct': 1}, {'value': 'sq_104', 'Data_Type': 'comparison', 'Chart_Type': 'Bar_4', 'Correct': 1}, {'value': 'sq_105', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Bubble_5', 'Correct': 1}, {'value': 'sq_106', 'Data_Type': 'valuevslocation', 'Chart_Type': 'Bar_6', 'Correct': 1}, {'value': 'sq_107', 'Data_Type': 'valuevsvalue', 'Chart_Type': 'Bubble_7', 'Correct': 1}, {'value': 'sq_108', 'Data_Type': 'valuevstime', 'Chart_Type': 'Table_8', 'Correct': 1}, {'value': 'sq_109', 'Data_Type': 'comparison', 'Chart_Type': 'Table_9', 'Correct': 1}, {'value': 'sq_110', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Tree_10', 'Correct': 1}, {'value': 'sq_111', 'Data_Type': 'valuevsvalue', 'Chart_Type': 'Scatter_11', 'Correct': 1}, {'value': 'sq_112', 'Data_Type': 'comparison', 'Chart_Type': 'Pie_12', 'Correct': 1}, {'value': 'sq_113', 'Data_Type': 'valuevstime', 'Chart_Type': 'Line_13', 'Correct': 1}, {'value': 'sq_114', 'Data_Type': 'valuevslocation', 'Chart_Type': 'Map_14', 'Correct': 1}, {'value': 'sq_115', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Pie_15', 'Correct': 1}]}
# 253466c1d3a2db2135c84157f88254a3e04778190a0646781b
#                                             Survey_ID   value  \
# 0   253466c1d3a2db2135c84157f88254a3e04778190a0646...  sq_101
# 1   253466c1d3a2db2135c84157f88254a3e04778190a0646...  sq_102
# 2   253466c1d3a2db2135c84157f88254a3e04778190a0646...  sq_103
# 3   253466c1d3a2db2135c84157f88254a3e04778190a0646...  sq_104
# 4   253466c1d3a2db2135c84157f88254a3e04778190a0646...  sq_105
# 5   253466c1d3a2db2135c84157f88254a3e04778190a0646...  sq_106
# 6   253466c1d3a2db2135c84157f88254a3e04778190a0646...  sq_107
# 7   253466c1d3a2db2135c84157f88254a3e04778190a0646...  sq_108
# 8   253466c1d3a2db2135c84157f88254a3e04778190a0646...  sq_109
# 9   253466c1d3a2db2135c84157f88254a3e04778190a0646...  sq_110
# 10  253466c1d3a2db2135c84157f88254a3e04778190a0646...  sq_111
# 11  253466c1d3a2db2135c84157f88254a3e04778190a0646...  sq_112
# 12  253466c1d3a2db2135c84157f88254a3e04778190a0646...  sq_113
# 13  253466c1d3a2db2135c84157f88254a3e04778190a0646...  sq_114
# 14  253466c1d3a2db2135c84157f88254a3e04778190a0646...  sq_115
#
#           Data_Type  Chart_Type  Correct
# 0   categoryvsvalue       Bar_1        1
# 1   valuevslocation       Map_2        1
# 2       valuevstime     Rings_3        1
# 3        comparison       Bar_4        1
# 4   categoryvsvalue    Bubble_5        1
# 5   valuevslocation       Bar_6        1
# 6      valuevsvalue    Bubble_7        1
# 7       valuevstime     Table_8        1
# 8        comparison     Table_9        1
# 9   categoryvsvalue     Tree_10        1
# 10     valuevsvalue  Scatter_11        1
# 11       comparison      Pie_12        1
# 12      valuevstime     Line_13        1
# 13  valuevslocation      Map_14        1
# 14  categoryvsvalue      Pie_15        1
# 127.0.0.1 - - [02/Feb/2020 17:03:15] "OPTIONS /postjson HTTP/1.1" 200 -
# True
# {'Survey_ID': 'fd53156e3cd87ddff86459e4d6a65a60cd0da958e28cd56571', 'result': [{'value': 'sq_101', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Bar_1', 'Correct': 1}, {'value': 'sq_102', 'Data_Type': 'valuevslocation', 'Chart_Type': 'Map_2', 'Correct': 1}, {'value': 'sq_103', 'Data_Type': 'valuevstime', 'Chart_Type': 'Rings_3', 'Correct': 1}, {'value': 'sq_104', 'Data_Type': 'comparison', 'Chart_Type': 'Bar_4', 'Correct': 1}, {'value': 'sq_105', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Bubble_5', 'Correct': 1}, {'value': 'sq_106', 'Data_Type': 'valuevslocation', 'Chart_Type': 'Bar_6', 'Correct': 1}, {'value': 'sq_107', 'Data_Type': 'valuevsvalue', 'Chart_Type': 'Bubble_7', 'Correct': 1}, {'value': 'sq_108', 'Data_Type': 'valuevstime', 'Chart_Type': 'Table_8', 'Correct': 1}, {'value': 'sq_109', 'Data_Type': 'comparison', 'Chart_Type': 'Table_9', 'Correct': 1}, {'value': 'sq_110', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Tree_10', 'Correct': 1}, {'value': 'sq_111', 'Data_Type': 'valuevsvalue', 'Chart_Type': 'Scatter_11', 'Correct': 1}, {'value': 'sq_112', 'Data_Type': 'comparison', 'Chart_Type': 'Pie_12', 'Correct': 1}, {'value': 'sq_113', 'Data_Type': 'valuevstime', 'Chart_Type': 'Line_13', 'Correct': 1}, {'value': 'sq_114', 'Data_Type': 'valuevslocation', 'Chart_Type': 'Map_14', 'Correct': 1}, {'value': 'sq_115', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Pie_15', 'Correct': 1}]}
# fd53156e3cd87ddff86459e4d6a65a60cd0da958e28cd56571
#                                             Survey_ID   value  \
# 0   fd53156e3cd87ddff86459e4d6a65a60cd0da958e28cd5...  sq_101
# 1   fd53156e3cd87ddff86459e4d6a65a60cd0da958e28cd5...  sq_102
# 2   fd53156e3cd87ddff86459e4d6a65a60cd0da958e28cd5...  sq_103
# 3   fd53156e3cd87ddff86459e4d6a65a60cd0da958e28cd5...  sq_104
# 4   fd53156e3cd87ddff86459e4d6a65a60cd0da958e28cd5...  sq_105
# 5   fd53156e3cd87ddff86459e4d6a65a60cd0da958e28cd5...  sq_106
# 6   fd53156e3cd87ddff86459e4d6a65a60cd0da958e28cd5...  sq_107
# 7   fd53156e3cd87ddff86459e4d6a65a60cd0da958e28cd5...  sq_108
# 8   fd53156e3cd87ddff86459e4d6a65a60cd0da958e28cd5...  sq_109
# 9   fd53156e3cd87ddff86459e4d6a65a60cd0da958e28cd5...  sq_110
# 10  fd53156e3cd87ddff86459e4d6a65a60cd0da958e28cd5...  sq_111
# 11  fd53156e3cd87ddff86459e4d6a65a60cd0da958e28cd5...  sq_112
# 12  fd53156e3cd87ddff86459e4d6a65a60cd0da958e28cd5...  sq_113
# 13  fd53156e3cd87ddff86459e4d6a65a60cd0da958e28cd5...  sq_114
# 14  fd53156e3cd87ddff86459e4d6a65a60cd0da958e28cd5...  sq_115
#
#           Data_Type  Chart_Type  Correct
# 0   categoryvsvalue       Bar_1        1
# 1   valuevslocation       Map_2        1
# 2       valuevstime     Rings_3        1
# 3        comparison       Bar_4        1
# 4   categoryvsvalue    Bubble_5        1
# 5   valuevslocation       Bar_6        1
# 6      valuevsvalue    Bubble_7        1
# 7       valuevstime     Table_8        1
# 8        comparison     Table_9        1
# 9   categoryvsvalue     Tree_10        1
# 10     valuevsvalue  Scatter_11        1
# 11       comparison      Pie_12        1
# 12      valuevstime     Line_13        1
# 13  valuevslocation      Map_14        1
# 14  categoryvsvalue      Pie_15        1
# 127.0.0.1 - - [02/Feb/2020 17:03:15] "POST /postjson HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Feb/2020 17:03:46] "OPTIONS /postjson HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Feb/2020 17:03:46] "POST /postjson HTTP/1.1" 200 -
# True
# {'Survey_ID': '40c9a9a20673a88fa50532d29915fb507c71f0a9efe6f386c9', 'result': [{'value': 'sq_101', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Bar_1', 'Correct': 1}, {'value': 'sq_102', 'Data_Type': 'valuevslocation', 'Chart_Type': 'Map_2', 'Correct': 1}, {'value': 'sq_103', 'Data_Type': 'valuevstime', 'Chart_Type': 'Rings_3', 'Correct': 1}, {'value': 'sq_104', 'Data_Type': 'comparison', 'Chart_Type': 'Bar_4', 'Correct': 1}, {'value': 'sq_105', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Bubble_5', 'Correct': 1}, {'value': 'sq_106', 'Data_Type': 'valuevslocation', 'Chart_Type': 'Bar_6', 'Correct': 1}, {'value': 'sq_107', 'Data_Type': 'valuevsvalue', 'Chart_Type': 'Bubble_7', 'Correct': 1}, {'value': 'sq_108', 'Data_Type': 'valuevstime', 'Chart_Type': 'Table_8', 'Correct': 1}, {'value': 'sq_109', 'Data_Type': 'comparison', 'Chart_Type': 'Table_9', 'Correct': 1}, {'value': 'sq_110', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Tree_10', 'Correct': 1}, {'value': 'sq_111', 'Data_Type': 'valuevsvalue', 'Chart_Type': 'Scatter_11', 'Correct': 1}, {'value': 'sq_112', 'Data_Type': 'comparison', 'Chart_Type': 'Pie_12', 'Correct': 1}, {'value': 'sq_113', 'Data_Type': 'valuevstime', 'Chart_Type': 'Line_13', 'Correct': 1}, {'value': 'sq_114', 'Data_Type': 'valuevslocation', 'Chart_Type': 'Map_14', 'Correct': 1}, {'value': 'sq_115', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Pie_15', 'Correct': 1}]}
# 40c9a9a20673a88fa50532d29915fb507c71f0a9efe6f386c9
#                                             Survey_ID   value  \
# 0   40c9a9a20673a88fa50532d29915fb507c71f0a9efe6f3...  sq_101
# 1   40c9a9a20673a88fa50532d29915fb507c71f0a9efe6f3...  sq_102
# 2   40c9a9a20673a88fa50532d29915fb507c71f0a9efe6f3...  sq_103
# 3   40c9a9a20673a88fa50532d29915fb507c71f0a9efe6f3...  sq_104
# 4   40c9a9a20673a88fa50532d29915fb507c71f0a9efe6f3...  sq_105
# 5   40c9a9a20673a88fa50532d29915fb507c71f0a9efe6f3...  sq_106
# 6   40c9a9a20673a88fa50532d29915fb507c71f0a9efe6f3...  sq_107
# 7   40c9a9a20673a88fa50532d29915fb507c71f0a9efe6f3...  sq_108
# 8   40c9a9a20673a88fa50532d29915fb507c71f0a9efe6f3...  sq_109
# 9   40c9a9a20673a88fa50532d29915fb507c71f0a9efe6f3...  sq_110
# 10  40c9a9a20673a88fa50532d29915fb507c71f0a9efe6f3...  sq_111
# 11  40c9a9a20673a88fa50532d29915fb507c71f0a9efe6f3...  sq_112
# 12  40c9a9a20673a88fa50532d29915fb507c71f0a9efe6f3...  sq_113
# 13  40c9a9a20673a88fa50532d29915fb507c71f0a9efe6f3...  sq_114
# 14  40c9a9a20673a88fa50532d29915fb507c71f0a9efe6f3...  sq_115
#
#           Data_Type  Chart_Type  Correct
# 0   categoryvsvalue       Bar_1        1
# 1   valuevslocation       Map_2        1
# 2       valuevstime     Rings_3        1
# 3        comparison       Bar_4        1
# 4   categoryvsvalue    Bubble_5        1
# 5   valuevslocation       Bar_6        1
# 6      valuevsvalue    Bubble_7        1
# 7       valuevstime     Table_8        1
# 8        comparison     Table_9        1
# 9   categoryvsvalue     Tree_10        1
# 10     valuevsvalue  Scatter_11        1
# 11       comparison      Pie_12        1
# 12      valuevstime     Line_13        1
# 13  valuevslocation      Map_14        1
# 14  categoryvsvalue      Pie_15        1
# 127.0.0.1 - - [02/Feb/2020 17:06:30] "OPTIONS /postjson HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Feb/2020 17:06:30] "POST /postjson HTTP/1.1" 200 -
# True
# {'Survey_ID': 'd9a68134d16029912e0d2cef42551f40ef18fe44685d5d370d', 'result': [{'value': 'sq_101', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Bar_1', 'Correct': 1}, {'value': 'sq_102', 'Data_Type': 'valuevslocation', 'Chart_Type': 'Map_2', 'Correct': 1}, {'value': 'sq_103', 'Data_Type': 'valuevstime', 'Chart_Type': 'Rings_3', 'Correct': 1}, {'value': 'sq_104', 'Data_Type': 'comparison', 'Chart_Type': 'Bar_4', 'Correct': 1}, {'value': 'sq_105', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Bubble_5', 'Correct': 1}, {'value': 'sq_106', 'Data_Type': 'valuevslocation', 'Chart_Type': 'Bar_6', 'Correct': 1}, {'value': 'sq_107', 'Data_Type': 'valuevsvalue', 'Chart_Type': 'Bubble_7', 'Correct': 1}, {'value': 'sq_108', 'Data_Type': 'valuevstime', 'Chart_Type': 'Table_8', 'Correct': 1}, {'value': 'sq_109', 'Data_Type': 'comparison', 'Chart_Type': 'Table_9', 'Correct': 1}, {'value': 'sq_110', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Tree_10', 'Correct': 1}, {'value': 'sq_111', 'Data_Type': 'valuevsvalue', 'Chart_Type': 'Scatter_11', 'Correct': 1}, {'value': 'sq_112', 'Data_Type': 'comparison', 'Chart_Type': 'Pie_12', 'Correct': 1}, {'value': 'sq_113', 'Data_Type': 'valuevstime', 'Chart_Type': 'Line_13', 'Correct': 1}, {'value': 'sq_114', 'Data_Type': 'valuevslocation', 'Chart_Type': 'Map_14', 'Correct': 1}, {'value': 'sq_115', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Pie_15', 'Correct': 1}]}
# d9a68134d16029912e0d2cef42551f40ef18fe44685d5d370d
#                                             Survey_ID   value  \
# 0   d9a68134d16029912e0d2cef42551f40ef18fe44685d5d...  sq_101
# 1   d9a68134d16029912e0d2cef42551f40ef18fe44685d5d...  sq_102
# 2   d9a68134d16029912e0d2cef42551f40ef18fe44685d5d...  sq_103
# 3   d9a68134d16029912e0d2cef42551f40ef18fe44685d5d...  sq_104
# 4   d9a68134d16029912e0d2cef42551f40ef18fe44685d5d...  sq_105
# 5   d9a68134d16029912e0d2cef42551f40ef18fe44685d5d...  sq_106
# 6   d9a68134d16029912e0d2cef42551f40ef18fe44685d5d...  sq_107
# 7   d9a68134d16029912e0d2cef42551f40ef18fe44685d5d...  sq_108
# 8   d9a68134d16029912e0d2cef42551f40ef18fe44685d5d...  sq_109
# 9   d9a68134d16029912e0d2cef42551f40ef18fe44685d5d...  sq_110
# 10  d9a68134d16029912e0d2cef42551f40ef18fe44685d5d...  sq_111
# 11  d9a68134d16029912e0d2cef42551f40ef18fe44685d5d...  sq_112
# 12  d9a68134d16029912e0d2cef42551f40ef18fe44685d5d...  sq_113
# 13  d9a68134d16029912e0d2cef42551f40ef18fe44685d5d...  sq_114
# 14  d9a68134d16029912e0d2cef42551f40ef18fe44685d5d...  sq_115
#
#           Data_Type  Chart_Type  Correct
# 0   categoryvsvalue       Bar_1        1
# 1   valuevslocation       Map_2        1
# 2       valuevstime     Rings_3        1
# 3        comparison       Bar_4        1
# 4   categoryvsvalue    Bubble_5        1
# 5   valuevslocation       Bar_6        1
# 6      valuevsvalue    Bubble_7        1
# 7       valuevstime     Table_8        1
# 8        comparison     Table_9        1
# 9   categoryvsvalue     Tree_10        1
# 10     valuevsvalue  Scatter_11        1
# 11       comparison      Pie_12        1
# 12      valuevstime     Line_13        1
# 13  valuevslocation      Map_14        1
# 14  categoryvsvalue      Pie_15        1
# 127.0.0.1 - - [02/Feb/2020 17:48:44] "OPTIONS /postjson HTTP/1.1" 200 -
# True
# {'Survey_ID': '44f013bfe9e2b822aa0139d97e9caea59bd52ad128f059901c', 'result': [{'value': 'sq_101', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Bar_1', 'Correct': 0}, {'value': 'sq_102', 'Data_Type': 'valuevslocation', 'Chart_Type': 'Map_2', 'Correct': 0}, {'value': 'sq_103', 'Data_Type': 'valuevstime', 'Chart_Type': 'Rings_3', 'Correct': 1}, {'value': 'sq_104', 'Data_Type': 'comparison', 'Chart_Type': 'Bar_4', 'Correct': 1}, {'value': 'sq_105', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Bubble_5', 'Correct': 1}, {'value': 'sq_106', 'Data_Type': 'valuevslocation', 'Chart_Type': 'Bar_6', 'Correct': 0}, {'value': 'sq_107', 'Data_Type': 'valuevsvalue', 'Chart_Type': 'Bubble_7', 'Correct': 0}, {'value': 'sq_108', 'Data_Type': 'valuevstime', 'Chart_Type': 'Table_8', 'Correct': 1}, {'value': 'sq_109', 'Data_Type': 'comparison', 'Chart_Type': 'Table_9', 'Correct': 1}, {'value': 'sq_110', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Tree_10', 'Correct': 0}, {'value': 'sq_111', 'Data_Type': 'valuevsvalue', 'Chart_Type': 'Scatter_11', 'Correct': 0}, {'value': 'sq_112', 'Data_Type': 'comparison', 'Chart_Type': 'Pie_12', 'Correct': 1}, {'value': 'sq_113', 'Data_Type': 'valuevstime', 'Chart_Type': 'Line_13', 'Correct': 0}, {'value': 'sq_114', 'Data_Type': 'valuevslocation', 'Chart_Type': 'Map_14', 'Correct': 0}, {'value': 'sq_115', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Pie_15', 'Correct': 0}]}
# 44f013bfe9e2b822aa0139d97e9caea59bd52ad128f059901c
#                                             Survey_ID   value  \
# 0   44f013bfe9e2b822aa0139d97e9caea59bd52ad128f059...  sq_101
# 1   44f013bfe9e2b822aa0139d97e9caea59bd52ad128f059...  sq_102
# 2   44f013bfe9e2b822aa0139d97e9caea59bd52ad128f059...  sq_103
# 3   44f013bfe9e2b822aa0139d97e9caea59bd52ad128f059...  sq_104
# 4   44f013bfe9e2b822aa0139d97e9caea59bd52ad128f059...  sq_105
# 5   44f013bfe9e2b822aa0139d97e9caea59bd52ad128f059...  sq_106
# 6   44f013bfe9e2b822aa0139d97e9caea59bd52ad128f059...  sq_107
# 7   44f013bfe9e2b822aa0139d97e9caea59bd52ad128f059...  sq_108
# 8   44f013bfe9e2b822aa0139d97e9caea59bd52ad128f059...  sq_109
# 9   44f013bfe9e2b822aa0139d97e9caea59bd52ad128f059...  sq_110
# 10  44f013bfe9e2b822aa0139d97e9caea59bd52ad128f059...  sq_111
# 11  44f013bfe9e2b822aa0139d97e9caea59bd52ad128f059...  sq_112
# 12  44f013bfe9e2b822aa0139d97e9caea59bd52ad128f059...  sq_113
# 13  44f013bfe9e2b822aa0139d97e9caea59bd52ad128f059...  sq_114
# 14  44f013bfe9e2b822aa0139d97e9caea59bd52ad128f059...  sq_115
#
#           Data_Type  Chart_Type  Correct
# 0   categoryvsvalue       Bar_1        0
# 1   valuevslocation       Map_2        0
# 2       valuevstime     Rings_3        1
# 3        comparison       Bar_4        1
# 4   categoryvsvalue    Bubble_5        1
# 5   valuevslocation       Bar_6        0
# 6      valuevsvalue    Bubble_7        0
# 7       valuevstime     Table_8        1
# 8        comparison     Table_9        1
# 9   categoryvsvalue     Tree_10        0
# 10     valuevsvalue  Scatter_11        0
# 11       comparison      Pie_12        1
# 12      valuevstime     Line_13        0
# 13  valuevslocation      Map_14        0
# 14  categoryvsvalue      Pie_15        0
# [2020-02-02 17:49:04,086] ERROR in app: Exception on /postjson [POST]
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py", line 691, in _read_bytes
#     data = self._rfile.read(num_bytes)
#   File "C:\ProgramData\Anaconda3\lib\socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py", line 1249, in _execute_context
#     cursor, statement, parameters, context
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py", line 580, in do_execute
#     cursor.execute(statement, parameters)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py", line 170, in execute
#     result = self._query(query)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py", line 328, in _query
#     conn.query(q)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py", line 517, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py", line 732, in _read_query_result
#     result.read()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py", line 1075, in read
#     first_packet = self.connection._read_packet()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py", line 657, in _read_packet
#     packet_header = self._read_bytes(4)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py", line 699, in _read_bytes
#     "Lost connection to MySQL server during query (%s)" % (e,))
# pymysql.err.OperationalError: (2013, 'Lost connection to MySQL server during query ([WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond)')
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask_cors\extension.py", line 161, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-11-3b9006dee415>", line 28, in postJsonHandler
#     survey_df.to_sql(con=conn, name='survey_results', if_exists='append', index=False)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py", line 2712, in to_sql
#     method=method,
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py", line 518, in to_sql
#     method=method,
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py", line 1319, in to_sql
#     table.create()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py", line 641, in create
#     if self.exists():
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py", line 628, in exists
#     return self.pd_sql.has_table(self.name, self.schema)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py", line 1344, in has_table
#     self.connectable.dialect.has_table, name, schema or self.meta.schema
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py", line 1612, in run_callable
#     return callable_(self, *args, **kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\base.py", line 2361, in has_table
#     ).execute(st)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py", line 982, in execute
#     return self._execute_text(object_, multiparams, params)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py", line 1155, in _execute_text
#     parameters,
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py", line 1253, in _execute_context
#     e, statement, parameters, cursor, context
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py", line 1473, in _handle_dbapi_exception
#     util.raise_from_cause(sqlalchemy_exception, exc_info)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py", line 398, in raise_from_cause
#     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py", line 152, in reraise
#     raise value.with_traceback(tb)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py", line 1249, in _execute_context
#     cursor, statement, parameters, context
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py", line 580, in do_execute
#     cursor.execute(statement, parameters)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py", line 170, in execute
#     result = self._query(query)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py", line 328, in _query
#     conn.query(q)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py", line 517, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py", line 732, in _read_query_result
#     result.read()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py", line 1075, in read
#     first_packet = self.connection._read_packet()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py", line 657, in _read_packet
#     packet_header = self._read_bytes(4)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py", line 699, in _read_bytes
#     "Lost connection to MySQL server during query (%s)" % (e,))
# sqlalchemy.exc.OperationalError: (pymysql.err.OperationalError) (2013, 'Lost connection to MySQL server during query ([WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond)')
# [SQL: DESCRIBE `survey_results`]
# (Background on this error at: http://sqlalche.me/e/e3q8)
# 127.0.0.1 - - [02/Feb/2020 17:49:04] "POST /postjson HTTP/1.1" 500 -
# 127.0.0.1 - - [02/Feb/2020 17:52:25] "OPTIONS /postjson HTTP/1.1" 200 -
# [2020-02-02 17:52:25,459] ERROR in app: Exception on /postjson [POST]
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py", line 1179, in _execute_context
#     context = constructor(dialect, self, conn, *args)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py", line 937, in _init_statement
#     self.cursor = self.create_cursor()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py", line 1070, in create_cursor
#     return self._dbapi_connection.cursor()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py", line 965, in cursor
#     return self.connection.cursor(*args, **kwargs)
# AttributeError: 'NoneType' object has no attribute 'cursor'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask_cors\extension.py", line 161, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-11-3b9006dee415>", line 28, in postJsonHandler
#     survey_df.to_sql(con=conn, name='survey_results', if_exists='append', index=False)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py", line 2712, in to_sql
#     method=method,
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py", line 518, in to_sql
#     method=method,
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py", line 1319, in to_sql
#     table.create()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py", line 641, in create
#     if self.exists():
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py", line 628, in exists
#     return self.pd_sql.has_table(self.name, self.schema)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py", line 1344, in has_table
#     self.connectable.dialect.has_table, name, schema or self.meta.schema
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py", line 1612, in run_callable
#     return callable_(self, *args, **kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\base.py", line 2361, in has_table
#     ).execute(st)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py", line 982, in execute
#     return self._execute_text(object_, multiparams, params)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py", line 1155, in _execute_text
#     parameters,
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py", line 1182, in _execute_context
#     e, util.text_type(statement), parameters, None, None
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py", line 1473, in _handle_dbapi_exception
#     util.raise_from_cause(sqlalchemy_exception, exc_info)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py", line 398, in raise_from_cause
#     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py", line 152, in reraise
#     raise value.with_traceback(tb)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py", line 1179, in _execute_context
#     context = constructor(dialect, self, conn, *args)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py", line 937, in _init_statement
#     self.cursor = self.create_cursor()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py", line 1070, in create_cursor
#     return self._dbapi_connection.cursor()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py", line 965, in cursor
#     return self.connection.cursor(*args, **kwargs)
# sqlalchemy.exc.StatementError: (builtins.AttributeError) 'NoneType' object has no attribute 'cursor'
# [SQL: DESCRIBE `survey_results`]
# 127.0.0.1 - - [02/Feb/2020 17:52:25] "POST /postjson HTTP/1.1" 500 -
# True
# {'Survey_ID': '77ce719f02b3f65c28869372821844cba3dfa4ec1597245aa1', 'result': [{'value': 'sq_101', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Bar_1', 'Correct': 1}, {'value': 'sq_102', 'Data_Type': 'valuevslocation', 'Chart_Type': 'Map_2', 'Correct': 0}, {'value': 'sq_103', 'Data_Type': 'valuevstime', 'Chart_Type': 'Rings_3', 'Correct': 1}, {'value': 'sq_104', 'Data_Type': 'comparison', 'Chart_Type': 'Bar_4', 'Correct': 1}, {'value': 'sq_105', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Bubble_5', 'Correct': 0}, {'value': 'sq_106', 'Data_Type': 'valuevslocation', 'Chart_Type': 'Bar_6', 'Correct': 0}, {'value': 'sq_107', 'Data_Type': 'valuevsvalue', 'Chart_Type': 'Bubble_7', 'Correct': 0}, {'value': 'sq_108', 'Data_Type': 'valuevstime', 'Chart_Type': 'Table_8', 'Correct': 1}, {'value': 'sq_109', 'Data_Type': 'comparison', 'Chart_Type': 'Table_9', 'Correct': 1}, {'value': 'sq_110', 'Data_Type': 'categoryvsvalue', 'Chart_Type': 'Tree_10', 'Correct': 0}]}
# 77ce719f02b3f65c28869372821844cba3dfa4ec1597245aa1
#                                            Survey_ID   value        Data_Type  \
# 0  77ce719f02b3f65c28869372821844cba3dfa4ec159724...  sq_101  categoryvsvalue
# 1  77ce719f02b3f65c28869372821844cba3dfa4ec159724...  sq_102  valuevslocation
# 2  77ce719f02b3f65c28869372821844cba3dfa4ec159724...  sq_103      valuevstime
# 3  77ce719f02b3f65c28869372821844cba3dfa4ec159724...  sq_104       comparison
# 4  77ce719f02b3f65c28869372821844cba3dfa4ec159724...  sq_105  categoryvsvalue
# 5  77ce719f02b3f65c28869372821844cba3dfa4ec159724...  sq_106  valuevslocation
# 6  77ce719f02b3f65c28869372821844cba3dfa4ec159724...  sq_107     valuevsvalue
# 7  77ce719f02b3f65c28869372821844cba3dfa4ec159724...  sq_108      valuevstime
# 8  77ce719f02b3f65c28869372821844cba3dfa4ec159724...  sq_109       comparison
# 9  77ce719f02b3f65c28869372821844cba3dfa4ec159724...  sq_110  categoryvsvalue
#
#   Chart_Type  Correct
# 0      Bar_1        1
# 1      Map_2        0
# 2    Rings_3        1
# 3      Bar_4        1
# 4   Bubble_5        0
# 5      Bar_6        0
# 6   Bubble_7        0
# 7    Table_8        1
# 8    Table_9        1
# 9    Tree_10        0

# %%
parsed = json.loads(content)
print json.dumps(parsed, indent=4, sort_keys=True)

# %%
# def update_survey():
#     orders_entries = []
#     for orders in data["all_orders"]:
#         new_entry = SalesOrders(order_id=orders['id'],
#                                 order_number=orders['number'])
#         orders_entries.append(new_entry)
#     db.session.add_all(orders_entries)
#     db.session.commit()


# if __name__ == "__main__":
#     app.run(debug=True)

# %%
# @app.route("/send", methods=["GET", "POST"])
# def send():
#     if request.method == "POST":
#         nickname = request.form["nickname"]
#         age = request.form["age"]
#         pet = Pet(nickname=nickname, age=age)
#         db.session.add(pet)
#         db.session.commit()

#         return "Thanks for the form data!"

#     return render_template("form.html")
